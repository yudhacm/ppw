# %% [markdown]
# # **Crawling PTA Trunojoyo (Manajemen)**

# %% [markdown]
# Crawling adalah proses otomatis dalam mengumpulkan data atau informasi dari internet menggunakan program yang disebut web crawler (atau bot). Web crawler bekerja dengan cara mengunjungi halaman-halaman web, membaca konten, lalu menyimpannya agar dapat diproses lebih lanjut.
#
# Secara umum, web crawling adalah tahapan awal data mining di web.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re, sys, time
from concurrent.futures import ThreadPoolExecutor, as_completed

# %% [markdown]
# ### **Tentukan Website yang Ingin di Crawling**
#
# Disini saya ingin crawling dari website PTA Trunojoyo dan lebih spesifik hanya ke prodi manajemen

# %%
BASE_URL = "https://pta.trunojoyo.ac.id/c_search/byprod"

# %% [markdown]
# ## **Proses Crawling PTA**
#
# Kita akan mengambil dari PTA khsusu untuk prodi manajemen dan hanya mengambil judul, penulis, pembimbing satu dan dua serta abstrak dalam bahasa indonesia

# %%
def get_max_page(prodi_id):
    url = f"{BASE_URL}/{prodi_id}/1"
    r = requests.get(url)
    soup = BeautifulSoup(r.content, "html.parser")

    last_page = soup.select_one('ol.pagination a:contains("»")')
    if last_page and "href" in last_page.attrs:
        href = last_page["href"]
        max_page = int(href.split("/")[-1])
        return max_page
    return 1

# %% [markdown]
# Fungsi `get_max_page(prodi_id)` dipakai untuk mencari tahu ada berapa halaman data (pagination) pada sebuah website untuk suatu program studi (`prodi_id`). Caranya: fungsi membuka halaman pertama, lalu mengecek apakah ada tombol menuju halaman terakhir (»). Jika ada, dia ambil angka terakhir dari link tersebut sebagai jumlah maksimal halaman. Kalau tidak ada tombol pagination, diasumsikan cuma ada 1 halaman.
#
# 1. Buat URL halaman pertama berdasarkan `BASE_URL` dan `prodi_id`.
#
# 2. Ambil isi halaman dengan` requests.get`.
#
# 3. Parsing HTML dengan BeautifulSoup.
#
# 4. Cari tombol pagination terakhir (yang ditandai dengan simbol `»`).
#
# 5. Kalau tombol ada → ambil nomor halaman terakhir dari link (`href`).
#
# 6. Kalau tidak ada → berarti hanya ada 1 halaman.

# %%
def print_progress(current_page, total_pages):
    percent = (current_page / total_pages) * 100
    bar_length = 20
    filled_length = int(bar_length * current_page // total_pages)
    bar = '█' * filled_length + '-' * (bar_length - filled_length)
    sys.stdout.write(f'\rPage {current_page}/{total_pages} [{bar}] {percent:.2f}%')
    sys.stdout.flush()
    if current_page == total_pages:
        sys.stdout.write('\n')

# %% [markdown]
# Fungsi `print_progress(current_page, total_pages)` digunakan untuk menampilkan progress bar di terminal agar kita bisa memantau sejauh mana proses sudah berjalan. Pertama, fungsi ini menghitung persentase berdasarkan halaman yang sedang diproses dibandingkan total halaman. Lalu, dibuat progress bar dengan panjang tetap (20 karakter), diisi dengan simbol blok `█` untuk bagian yang sudah selesai dan tanda `-` untuk bagian yang belum selesai. Setelah itu, progress bar ditampilkan di baris yang sama menggunakan `\r`, sehingga tampilannya selalu terupdate tanpa membuat baris baru. Terakhir, ketika proses mencapai halaman terakhir, fungsi menambahkan baris baru supaya tampilan rapi.

# %%
def crawl_detail(link_keluar, prodi):
    try:
        id_match = re.search(r"/detail/(\d+)", link_keluar)
        pta_id = id_match.group(1) if id_match else None

        response = requests.get(link_keluar, timeout=10)
        soup1 = BeautifulSoup(response.content, "html.parser")
        isi = soup1.select_one('div#content_journal')

        judul = isi.select_one('a.title').text.strip()
        penulis = isi.select_one('span:contains("Penulis")').text.split(' : ')[1]
        pembimbing_pertama = isi.select_one('span:contains("Dosen Pembimbing I")').text.split(' : ')[1]
        pembimbing_kedua = isi.select_one('span:contains("Dosen Pembimbing II")').text.split(' :')[1]

        paragraf = isi.select('p[align="justify"]')
        abstrak_id = paragraf[0].get_text(strip=True) if len(paragraf) > 0 else "N/A"
        abstrak_en = paragraf[1].get_text(strip=True) if len(paragraf) > 1 else "N/A"

        return {
            "id": pta_id,
            "penulis": penulis,
            "judul": judul,
            "abstrak_id": abstrak_id,
            "pembimbing_pertama": pembimbing_pertama,
            "pembimbing_kedua": pembimbing_kedua,
            "prodi": prodi,
        }
    except Exception:
        return None

def crawl_manajemen():
    start_time = time.time()
    results = []

    prodi_id = 7 # id prodi manajemen
    max_page = get_max_page(prodi_id)

    for j in range(1, max_page + 1):
        url = f"{BASE_URL}/{prodi_id}/{j}"
        r = requests.get(url)
        soup = BeautifulSoup(r.content, "html.parser")
        jurnals = soup.select('li[data-cat="#luxury"]')

        isii = soup.select_one('div#begin')
        if not isii:
            continue
        prodi_full = isii.select_one('h2').text.strip()
        prodi = prodi_full.replace("Journal Jurusan ", "")

        links = [jurnal.select_one('a.gray.button')['href'] for jurnal in jurnals]

        with ThreadPoolExecutor(max_workers=10) as executor:
            future_to_link = {executor.submit(crawl_detail, link, prodi): link for link in links}
            for future in as_completed(future_to_link):
                data = future.result()
                if data:
                    results.append(data)

        print_progress(j, max_page)

    df = pd.DataFrame(results)
    df.to_csv("pta_manajemen.csv", index=False, encoding="utf-8-sig")

    end_time = time.time()
    elapsed = int(end_time - start_time)
    jam, sisa = divmod(elapsed, 3600)
    menit, detik = divmod(sisa, 60)

    print("\n✅ Data Prodi Manajemen berhasil dikumpulkan!")
    print(f"📊 Total entri: {len(df)}")
    print(f"⏱️ Waktu eksekusi: {jam} jam {menit} menit {detik} detik")

    return df

# %%
crawl_manajemen()
# Out:
# /usr/local/lib/python3.12/dist-packages/soupsieve/css_parser.py:876: FutureWarning: The pseudo class ':contains' is deprecated, ':-soup-contains' should be used moving forward.
#   warnings.warn(  # noqa: B028
# Page 207/207 [████████████████████] 100.00%
#
# ✅ Data Prodi Manajemen berhasil dikumpulkan!
# 📊 Total entri: 1031
# ⏱️ Waktu eksekusi: 0 jam 15 menit 0 detik
#                 id                    penulis  \
# 0     080211100050            Wahyu Kurniawan
# 1     100211200002     Muhammad Zakaria Utomo
# 2     080211100044    Hendri Wahyudi Prayitno
# 3     090211200001                    Faishal
# 4     080211100070                    SATIYAH
# ...            ...                        ...
# 1026  160211100291            Uswatun Hasanah
# 1027  160211100071             Husnul Hotimah
# 1028  160211100030       INTAN YULLIA NINGSIH
# 1029  160211100041  Novia Prihastiwi Ningtyas
# 1030  160211100116          Widha Deby Andrea
#
#                                                   judul  \
# 0     PENGARUH GAYA KEPEMIMPINAN DEMOKRATIK TERHADAP...
# 1     Pengukuran Website Quality Pada Situs Sistem A...
# 2     PENGARUH KEPEMIMPINAN DAN KOMPENSASI TERHADAP ...
# 3     ANALISIS PERSEPSI BRAND ASSOCIATION MENURUT PE...
# 4     PENGARUH FAKTOR-FAKTOR PELATIHAN DAN PENGEMBAN...
# ...                                                 ...
# 1026  Pengaruh Pelatihan Dan Kompensasi Terhadap Pro...
# 1027  Analisis Cost Volume Profit Untuk Menentukan T...
# 1028  BAURAN PROMOSI PADA DEALER YAMAHA TRETAN MOTOR...
# 1029  ANALISA PENGARUH RASIO BOPO, LDR, ROA TERHADAP...
# 1030  Peran Teor Motivasi Herzberg Sebagai Mediator ...
#
#                                              abstrak_id  \
# 0
# 1     Aplikasi nyata pemanfaatan teknologi informasi...
# 2     Abstrak\r\nPenelitian ini menggunakan metode k...
# 3     Tujuan penelitian ini adalah untuk mengetahui ...
# 4     ABSTRAK\r\nSatiyah, Pengaruh Faktor-faktor Pel...
# ...                                                 ...
# 1026  ABSTRAK\nUswatun Hasanah, 160211100291, Pengar...
# 1027  ABSTRAK\nPenelitian ini bertujuan untuk menget...
# 1028  ABSTRAK\nPenelitian ini bertujuan: (1) Untuk m...
# 1029  Tujuan penelitian ini adalah untuk mengetahui ...
# 1030  Penelitian ini bertujuan untuk dapat mengetahu...
#
#                                  pembimbing_pertama  \
# 0                    Dr. Dra. Hj. Iriani Ismail, MM
# 1                       Dr. Ir. Nurita Andriani, MM
# 2                 Dra. Hj. S Anugrahini Irawati, MM
# 3                                   Nurita Andriani
# 4                Dra. Hj. S. Anugrahini Irawati, MM
# ...                                             ...
# 1026  Dr. Raden Mas Mochammad  Wispandono S.E ., MS
# 1027           Hj. Evaliati Amaniyah, S.E., M.S.M.
# 1028                 DR. MOHAMMAD ARIEF, S.E., M.M.
# 1029             Hj. Evaliati Amaniyah, S.E., M.S.M
# 1030             Mochammad Isa Anshori, S.E., M.Si.
#
#                         pembimbing_kedua      prodi
# 0     Dra. Hj. S. Anugrahini Irawati, MM  Manajemen
# 1              Nirma Kurriwati, SP, M.Si  Manajemen
# 2         Helmi Buyung Aulia,S,ST,SE,.MT  Manajemen
# 3                   Yustina Chrismardani  Manajemen
# 4        Helmi Buyung Aulia,S,ST.SE,M.MT  Manajemen
# ...                                  ...        ...
# 1026                                      Manajemen
# 1027                                      Manajemen
# 1028                                      Manajemen
# 1029                                      Manajemen
# 1030                                      Manajemen
#
# [1031 rows x 7 columns]

# %% [markdown]
# Fungsi `crawl_detail(link_keluar, prodi)` bertugas mengambil detail dari sebuah halaman jurnal. Pertama, fungsi mencoba mengekstrak ID PTA dari URL detail menggunakan regex. Kemudian, ia membuka halaman detail tersebut dengan `requests` dan mem-parsing isinya dengan BeautifulSoup. Dari halaman itu, fungsi mengambil informasi penting seperti judul, penulis, pembimbing I & II, serta abstrak bahasa Indonesia dan bahasa Inggris. Semua informasi tersebut dikembalikan dalam bentuk dictionary. Jika terjadi error, fungsi akan mengembalikan `None`.
#
# Fungsi `crawl_manajemen()` dipakai khusus untuk meng-crawl data jurnal pada Prodi Manajemen. Pertama, fungsi mencatat waktu mulai agar nanti bisa dihitung lama eksekusinya. Setelah itu, ia menentukan jumlah halaman maksimal dengan `get_max_page`. Lalu, untuk setiap halaman, fungsi membuka daftar jurnal, mengambil nama lengkap prodi, lalu mengumpulkan semua link menuju detail jurnal. Link-link ini kemudian diproses secara paralel dengan `ThreadPoolExecutor` agar lebih cepat, memanggil `crawl_detail` untuk setiap link.
#
# Hasil yang valid dikumpulkan dalam sebuah list, kemudian disimpan ke dalam CSV bernama `pta_manajemen.csv`. Setelah semua halaman selesai diproses, fungsi menghitung total entri, waktu eksekusi, dan menampilkannya dalam format jam-menit-detik. Pada akhirnya, fungsi mengembalikan data dalam bentuk DataFrame.

# %%
from google.colab import files
files.download("/content/pta_manajemen.csv")

# %% [markdown]
# Simpan dalam bentuk csv

# %% [markdown]
# ## **Crawling Link**
#
# Kali ini kita akan melakukan crawling link pada website labtia.trunojoyo. Tentukan link url daru website:

# %%
BASE_URL = "https://labtia.trunojoyo.ac.id/"
START_URL = "https://labtia.trunojoyo.ac.id/"
headers = {"User-Agent": "Mozilla/5.0"}

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin, urlparse
from collections import deque
import pandas as pd

visited = set()
edges = []  # simpan source -> target

def crawl(start_url, base_domain, max_pages=100, max_depth=3):
    queue = deque([(start_url, 0)])  # (url, depth)

    while queue and len(visited) < max_pages:
        url, depth = queue.popleft()

        if url in visited:
            continue
        visited.add(url)

        # stop kalau kedalaman melebihi max_depth
        if depth > max_depth:
            continue

        try:
            r = requests.get(url, timeout=10)
            if r.status_code != 200:
                continue
        except Exception as e:
            print(f"Gagal akses {url}: {e}")
            continue

        print(f"[{len(visited)}] Sedang di (depth {depth}): {url}")

        soup = BeautifulSoup(r.text, "html.parser")
        for link in soup.find_all("a", href=True):
            href = link['href']
            next_url = urljoin(url, href)
            parsed = urlparse(next_url)

            # hanya internal link
            if parsed.netloc == base_domain:
                # skip kalau masuk ke journals/*
                if "/journals/" in parsed.path.strip("/"):
                    continue

                # simpan relasi source -> target
                edges.append({
                    "source_url": url,
                    "target_url": next_url,
                    "depth": depth + 1
                })

                if next_url not in visited:
                    queue.append((next_url, depth + 1))


start_url = "https://labtia.trunojoyo.ac.id/"
base_domain = urlparse(start_url).netloc
crawl(start_url, base_domain, max_pages=20, max_depth=3)

# simpan ke CSV
df = pd.DataFrame(edges)
df.to_csv("hasil_crawl_edges.csv", index=False, encoding="utf-8")

print("\nTotal halaman unik:", len(visited))
print("Relasi source→target disimpan di 'hasil_crawl_edges.csv'")
# Out:
# [1] Sedang di (depth 0): https://labtia.trunojoyo.ac.id/
# [2] Sedang di (depth 1): http://labtia.trunojoyo.ac.id/
# [4] Sedang di (depth 1): http://labtia.trunojoyo.ac.id/p/about-us.html
# [5] Sedang di (depth 1): https://labtia.trunojoyo.ac.id/search
# [6] Sedang di (depth 1): https://labtia.trunojoyo.ac.id/#!
# [7] Sedang di (depth 1): https://labtia.trunojoyo.ac.id/p/contact.html
# [8] Sedang di (depth 1): https://labtia.trunojoyo.ac.id/search/label/PRAKTIKUM
# [9] Sedang di (depth 1): https://labtia.trunojoyo.ac.id/search/label/Publikasi
# [10] Sedang di (depth 1): https://labtia.trunojoyo.ac.id/2025/07/pengumuman-calon-wargalab-jurusan.html
# [11] Sedang di (depth 1): https://labtia.trunojoyo.ac.id/2024/09/jadwal-pratikum-semester-ganjil-tahun.html
# [12] Sedang di (depth 1): https://labtia.trunojoyo.ac.id/2025/09/jadwal-pratikum-semester-ganjil-tahun.html
# [13] Sedang di (depth 1): https://labtia.trunojoyo.ac.id/2024/07/pengumuman-calon-warga-lab-jurusan.html
# [14] Sedang di (depth 1): https://labtia.trunojoyo.ac.id/2018/10/anda-ingin-login-baca-selengkapnya.html
# [15] Sedang di (depth 1): http://labtia.trunojoyo.ac.id/p/microsoft-imagine-academy.html
# [16] Sedang di (depth 1): https://labtia.trunojoyo.ac.id/2019/03/pendaftaran-open-recruitment-warga-lab.html
# [17] Sedang di (depth 1): https://labtia.trunojoyo.ac.id/2018/05/ramadan-bersama-lab-bukan-paid-promote.html
# [18] Sedang di (depth 1): https://labtia.trunojoyo.ac.id/p/sitemap.html
#
# Total halaman unik: 20
# Relasi source→target disimpan di 'hasil_crawl_edges.csv'

# %%
df
# Out:
#                                          source_url  \
# 0                   https://labtia.trunojoyo.ac.id/
# 1                   https://labtia.trunojoyo.ac.id/
# 2                   https://labtia.trunojoyo.ac.id/
# 3                   https://labtia.trunojoyo.ac.id/
# 4                   https://labtia.trunojoyo.ac.id/
# ...                                             ...
# 1569  https://labtia.trunojoyo.ac.id/p/sitemap.html
# 1570  https://labtia.trunojoyo.ac.id/p/sitemap.html
# 1571  https://labtia.trunojoyo.ac.id/p/sitemap.html
# 1572  https://labtia.trunojoyo.ac.id/p/sitemap.html
# 1573  https://labtia.trunojoyo.ac.id/p/sitemap.html
#
#                                              target_url  depth
# 0                        http://labtia.trunojoyo.ac.id/      1
# 1                   https://labtia.trunojoyo.ac.id/mega      1
# 2                   https://labtia.trunojoyo.ac.id/mega      1
# 3                   https://labtia.trunojoyo.ac.id/mega      1
# 4                       https://labtia.trunojoyo.ac.id/      1
# ...                                                 ...    ...
# 1569  https://labtia.trunojoyo.ac.id/search/label/Pu...      2
# 1570   https://labtia.trunojoyo.ac.id/search/label/Tech      2
# 1571      https://labtia.trunojoyo.ac.id/p/contact.html      2
# 1572                    https://labtia.trunojoyo.ac.id/      2
# 1573      https://labtia.trunojoyo.ac.id/p/sitemap.html      2
#
# [1574 rows x 3 columns]

# %%
from google.colab import files
files.download("/content/hasil_crawl_edges.csv")

# %% [markdown]
# simpan dalam bentuk csv, untuk digunakan dalam data processing

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import re
from tabulate import tabulate

kategori_list = ["nasional", "bisnis", "tekno", "bola", "metro", "dunia"]
base_rss = "https://rss.tempo.co"

results = []

for kategori in kategori_list:
    rss_url = f"{base_rss}/{kategori}"
    print(f"Mengambil RSS dari: {rss_url}")
    resp = requests.get(rss_url, headers={"User-Agent": "Mozilla/5.0"})

    if resp.status_code != 200:
        print(f"Gagal mengambil RSS dari kategori: {kategori}")
        continue

    soup = BeautifulSoup(resp.content, "xml")
    items = soup.find_all("item")

    for item in items[:20]:
        link = item.find("link").text
        judul = item.find("title").text.strip()

        try:
            berita_id = link.split("/")[-1].split("-")[0]
        except:
            berita_id = None

        try:
            r = requests.get(link, headers={"User-Agent": "Mozilla/5.0"})
            if r.status_code != 200:
                print(f"Gagal membuka link: {link}")
                continue

            s = BeautifulSoup(r.text, "html.parser")

            isi_tag = s.find("div", id="content-wrapper")
            if isi_tag:
                for tag in isi_tag(["script", "style", "aside", "figure"]):
                    tag.decompose()

                isi_paragraf = isi_tag.find_all("p")
                isi = " ".join(p.get_text(" ", strip=True) for p in isi_paragraf)
                isi = re.sub(r"Baca juga.*?(?=[A-Z])", "", isi)

            else:
                isi = None

        except Exception as e:
            print(f"Error saat mengambil isi dari {link}: {e}")
            isi = None

        isi_ringkas = (isi[:200] + "...") if isi else "-"

        results.append([len(results)+1, berita_id, judul, kategori, isi_ringkas])
        time.sleep(1)

df = pd.DataFrame(results, columns=["No", "ID Berita", "Judul", "Kategori", "Isi"])

df.to_csv("berita_tempo.csv", index=False, encoding="utf-8-sig")

print(tabulate(df, headers="keys", tablefmt="grid", showindex=False))
# Out:
# Mengambil RSS dari: https://rss.tempo.co/nasional
# Mengambil RSS dari: https://rss.tempo.co/bisnis
# Mengambil RSS dari: https://rss.tempo.co/tekno
# Mengambil RSS dari: https://rss.tempo.co/bola
# Mengambil RSS dari: https://rss.tempo.co/metro
# Mengambil RSS dari: https://rss.tempo.co/dunia
# Gagal mengambil RSS dari kategori: dunia
# +------+-------------+-------------------------------------------------------------------------------------------------------+------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |   No | ID Berita   | Judul                                                                                                 | Kategori   | Isi                                                                                                                                                                                                         |
# +======+=============+=======================================================================================================+============+=============================================================================================================================================================================================================+
# |    1 | debat       | Debat Sengit Komisi II DPR dan Baleg Berebut Bahas Revisi UU Pemilu                                   | nasional   | SUASANA rapat koordinasi antara pimpinan komisi-komisi dengan Badan Legislasi Dewan Perwakilan Rakyat pada Rabu sore, 17 September 2025, sempat memanas. Momen itu terjadi saat Wakil Ketua Baleg Ahmad ... |
# +------+-------------+-------------------------------------------------------------------------------------------------------+------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |    2 | sengketa    | Sengketa Pilkada Ulang Barito Utara dan Papua Kandas di MK, Ini Alasannya                             | nasional   | MAHKAMAH Konstitusi ( MK ) menyelesaikan Permohonan Perselisihan Hasil Pemilihan Umum (PHPU) untuk Kabupaten Barito Utara dan Provinsi Papua pada Rabu, 17 September 2025. Ketua MK Suhartoyo membacakan... |
# +------+-------------+-------------------------------------------------------------------------------------------------------+------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |    3 | respons     | Respons Pemerintah dan Tentara soal MK Tolak Gugatan Uji Formil UU TNI                                | nasional   | WAKIL Menteri Hukum Eddy Hiariej menghormati putusan Mahkamah Konstitusi Nomor 81/PUU-XXIII/2025 yang menolak sepenuhnya gugatan uji formil atas Undang-Undang Tentara Nasional Indonesia atau UU TNI ya... |
# +------+-------------+-------------------------------------------------------------------------------------------------------+------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |    4 | rangkap     | Rangkap Jabatan Menpora dan Ketum PSSI, Erick Tunggu Putusan FIFA                                     | nasional   | MENTERI Pemuda dan Olahraga Erick Thohir belum mengetahui nasibnya sebagai Ketua Umum Persatuan Sepak Bola Seluruh Indonesia (PSSI). Erick menyerahkan keputusan itu kepada Federasi Sepak Bola Dunia at... |
# +------+-------------+-------------------------------------------------------------------------------------------------------+------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |    5 | hadiri      | Hadiri Acara The Taste of Papua, Fatma Saifullah Yusuf Suka Kelezatan Papeda                          | nasional   | INFO NASIONAL - Wakil Ketua Bidang 3 Solidaritas Perempuan Untuk Indonesia (SERUNI) Kabinet Merah Putih (KMP), Fatma Saifullah Yusuf, menghadiri acara bertajuk 'The Taste of Papua: A Journey of Gastro... |
# +------+-------------+-------------------------------------------------------------------------------------------------------+------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |    6 | istana      | Istana Akan Umumkan Anggota Tim Reformasi Kepolisian Pekan Ini                                        | nasional   | MENTERI Sekretaris Negara Prasetyo Hadi mengatakan susunan anggota dan instrumen hukum Tim Reformasi Kepolisian akan diumumkan dalam pekan ini. Namun, Prasetyo tidak menyebutkan tanggal pastinya....      |
# +------+-------------+-------------------------------------------------------------------------------------------------------+------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |    7 | istana      | Istana Ungkap Alasan Perubahan PCO Jadi Badan Komunikasi Pemerintah                                   | nasional   | MENTERI Sekretaris Negara Prasetyo Hadi mengatakan Badan Komunikasi Pemerintah merupakan bentuk transformasi Kantor Komunikasi Kepresidenan ( PCO ). Perubahan dilakukan untuk memperbaiki komunikasi ke... |
# +------+-------------+-------------------------------------------------------------------------------------------------------+------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |    8 | cahya       | Cahya Mata Keluarga Difabel Dapat Meraih Cita Lewat Sekolah Rakyat                                    | nasional   | INFO NASIONAL - Rumah kontrakan sederhana menjadi saksi bisu perjuangan keluarga difabel di Kelurahan Purwantoro, Kecamatan Belimbing, Kota Malang, Jawa Timur. Sekolah Rakyat menjadi jalan pembuka bag... |
# +------+-------------+-------------------------------------------------------------------------------------------------------+------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |    9 | cerita      | Cerita Angga Raka Berada di Lingkaran Prabowo                                                         | nasional   | PRESIDEN Prabowo Subianto melantik Angga Raka Prabowo sebagai Kepala Badan Komunikasi Pemerintah di Istana Negara, Jakarta Pusat, pada Rabu sore, 17 September 2025. Angga menggantikan Hasan Nasbi, yan... |
# +------+-------------+-------------------------------------------------------------------------------------------------------+------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |   10 | istana      | Istana soal Angga Raka Prabowo Rangkap 3 Jabatan: Kami Akan Evaluasi                                  | nasional   | ANGGA Raka Prabowo memegang tiga jabatan saat ini, yaitu sebagai Wakil Menteri Komunikasi dan Digital (Wamenkomdigi), Kepala Badan Komunikasi Pemerintah, dan Komisaris Utama (Komut) Telkom....            |
# +------+-------------+-------------------------------------------------------------------------------------------------------+------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |   11 | mensos      | Mensos Ajak Tokoh Lintas Agama Wujudkan Layanan Disabilitas Komprehensif                              | nasional   | INFO NASIONAL – Kementerian Sosial (Kemensos) bersama Komisi Nasional Disabilitas (KND) dan para tokoh lintas agama sepakat memperkuat sinergi strategis mewujudkan layanan disabilitas yang menyeluruh ... |
# +------+-------------+-------------------------------------------------------------------------------------------------------+------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |   12 | wamensos    | Wamensos Serahkan Santunan Korban Unjuk Rasa di Tangerang                                             | nasional   | INFO NASIONAL — Wakil Menteri Sosial (Wamensos) Agus Jabo Priyono menyerahkan santunan kepada keluarga mendiang Andika Lutfi Falah (16), korban unjuk rasa di Tigaraksa, Kabupaten Tangerang, Banten, pa... |
# +------+-------------+-------------------------------------------------------------------------------------------------------+------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |   13 | komisi      | Komisi II DPR Usul UU Pemilu hingga MD3 Masuk Prolegnas 2026                                          | nasional   | KOMISI II Dewan Perwakilan Rakyat (DPR) mengusulkan sejumlah rancangan undang-undang (RUU) untuk masuk program legislasi nasional atau Prolegnas prioritas 2026. Usulan ini tak jauh berbeda dengan yang... |
# +------+-------------+-------------------------------------------------------------------------------------------------------+------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |   14 | angga       | Angga Raka Masih Wamenkomdigi Meski Jadi Kepala Badan Komunikasi Pemerintah                           | nasional   | ANGGA Raka Prabowo masih memegang jabatan Wakil Menteri Komunikasi dan Digital meski sudah dilantik menjadi Kepala Badan Komunikasi Pemerintah. Angga Raka Prabowo menggantikan posisi Hasan Nasbi yang ... |
# +------+-------------+-------------------------------------------------------------------------------------------------------+------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |   15 | sederet     | Sederet Kontroversi Erick Thohir Selama Jadi Menteri BUMN                                             | nasional   | PRESIDEN Prabowo Subianto menggeser Erick Thohir dari posisi Menteri Badan Usaha Milik Negara (BUMN) ke Menteri Pemuda dan Olahraga, pada Rabu sore, 17 September 2025. Erick mengganti Ario Bimo Nandit... |
# +------+-------------+-------------------------------------------------------------------------------------------------------+------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |   16 | dissenting  | Dissenting Opinion, Empat Hakim MK Sarankan Perbaikan UU TNI dalam Dua Tahun                          | nasional   | EMPAT dari sembilan hakim Mahkamah Konstitusi (MK) menyatakan pendapat berbeda atau dissenting opinion dalam putusan uji formil Nomor 81/PUU-XXIII/2025 Undang-Undang Tentara Nasional (TNI). Keempat ha... |
# +------+-------------+-------------------------------------------------------------------------------------------------------+------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |   17 | empat       | Empat Tahun Monash University, Indonesia: Penggerak Transformasi Pendidikan dan Inovasi Berkelanjutan | nasional   | INFO NASIONAL - Setelah resmi beroperasi pada Oktober 2021, Monash University, Indonesia kini memasuki tahun keempat dengan pencapaian yang menegaskan perannya sebagai motor transformasi pendidikan, r... |
# +------+-------------+-------------------------------------------------------------------------------------------------------+------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |   18 | prabowo     | Prabowo Beri Kenaikan Pangkat Jenderal Kehormatan bagi Djamari Chaniago dan Ahmad Dofiri              | nasional   | PRESIDEN Prabowo Subianto memberikan kenaikan pangkat Jenderal Kehormatan kepada Djamari Chaniago dan Ahmad Dofiri di Istana Negara, Jakarta Pusat, Rabu, 17 September 2025. Menteri Sekretaris Negara P... |
# +------+-------------+-------------------------------------------------------------------------------------------------------+------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |   19 | prabowo     | Prabowo Masih Cari Sosok Menteri BUMN Pengganti Erick Thohir                                          | nasional   | MENTERI Sekretaris Negara Prasetyo Hadi menjelaskan alasan Menteri Badan Usaha Milik Negara (BUMN) belum ditunjuk ketika pelantikan pejabat di Istana Negara, Jakarta Pusat, Rabu, 17 September 2025. Pr... |
# +------+-------------+-------------------------------------------------------------------------------------------------------+------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |   20 | aliansi     | Aliansi Ojek Online Klaim DPR Sepakati Potongan 10 Persen untuk Aplikator                             | nasional   | ALIANSI pengemudi ojek online Garda Indonesia mengklaim para pimpinan DPR dan Komisi V telah menyepakati besaran potongan tarif bagi hasil antara pengemudi dengan aplikator usai audiensi....              |
# +------+-------------+-------------------------------------------------------------------------------------------------------+------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |   21 | dosen       | Dosen UGM Nilai Impor BBM Satu Pintu Lewat Pertamina Bakal Matikan SPBU Asing                         | bisnis     | DOSEN Fakultas Ekonomi Universitas Gadjah Mada (UGM), Fahmy Radhi, menilai rencana Kementerian Energi dan Sumber Daya Mineral (ESDM) mewajibkan impor bahan bakar minyak (BBM) untuk SPBU asing melalui ... |
# +------+-------------+-------------------------------------------------------------------------------------------------------+------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |   22 | knti        | KNTI Ungkap Dilema Proyek Modernisasi Kapal Nelayan                                                   | bisnis     | KESATUAN Nelayan Tradisional Indonesia (KNTI) menilai proyek modernisasi kapal nelayan berpotensi mengerdilkan nelayan kecil di wilayah penangkapan. “(Program ini) menghadirkan dilema serius bagi masa... |
# +------+-------------+-------------------------------------------------------------------------------------------------------+------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |   23 | esdm        | ESDM: Total Listrik dari Instalasi PLTP Sudah 2,71 Gigawatt                                           | bisnis     | KEMENTERIAN Energi dan Sumber Daya Mineral (ESDM) mencatat kapasitas listrik panas bumi ( PLTP ) terpasang di Indonesia telah mencapai 2,71 gigawatt (GW). Angka ini meningkat dari total kapasitas pada... |
# +------+-------------+-------------------------------------------------------------------------------------------------------+------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |   24 | ojek        | Ojek Online Tuntut Potongan Komisi 10 Persen. Grab: Masih Perlu Dikaji                                | bisnis     | PERUSAHAAN layanan transportasi berbasis aplikasi (aplikator) Grab Indonesia menilai aspirasi mitra pengemudi (driver) atau ojek online tentang potongan komisi di aplikasi maksimal 10 persen masih per... |
# +------+-------------+-------------------------------------------------------------------------------------------------------+------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |   25 | rmi         | RMI-NU DKI Desak Kemendag Setop Impor Food Tray MBG Bermasalah                                        | bisnis     | RABITHAH Ma'ahid Islamiyah Nahdlatul Ulama (RMI-NU) DKI Jakarta mendesak Kementerian Perdagangan melakukan moratorium izin impor food tray atau ompreng proyek makan bergizi gratis (MBG) karena temuan ... |
# +------+-------------+-------------------------------------------------------------------------------------------------------+------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |   26 | bni         | BNI Perkuat Integritas dan GCG Lewat Compliance Forum                                                 | bisnis     | INFO BISNIS - PT Bank Negara Indonesia (Persero) Tbk atau BNI menegaskan komitmennya dalam memperkuat penerapan tata kelola perusahaan yang baik dan budaya anti-korupsi. Hal ini diwujudkan melalui pen... |
# +------+-------------+-------------------------------------------------------------------------------------------------------+------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |   27 | kronologi   | Kronologi Temuan Ompreng MBG Impor Diduga Mengandung Minyak Babi                                      | bisnis     | Rabithah Ma'ahid Islamiyah Nahdlatul Ulama (RMI-NU) DKI Jakarta mengungkap dugaan penggunaan minyak babi dalam produksi food tray impor untuk program Makan Bergizi Gratis (MBG). Dugaan ini berawal dar... |
# +------+-------------+-------------------------------------------------------------------------------------------------------+------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |   28 | ojk         | OJK: Likuiditas Perbankan Meningkat Setelah Rp 200 Triliun Dialirkan ke Himbara                       | bisnis     | OTORITAS Jasa Keuangan ( OJK ) mengatakan bahwa likuiditas perbankan meningkat setelah pemerintah menempatkan dana Rp 200 triliun ke lima bank Badan Usaha Milik Negara (BUMN). “Setelah adanya penambah... |
# +------+-------------+-------------------------------------------------------------------------------------------------------+------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |   29 | kredit      | Kredit Perbankan Rp 2.372,11 Triliun Nganggur. BI: Pengusaha Wait and See                             | bisnis     | BANK Indonesia mencatat ada dana kredit perbankan yang menganggur atau undisbursed loan sebesar Rp 2.372,11 triliun pada Agustus 2025. Jumlah itu setara 22,71 persen dari plafon kredit yang tersedia d... |
# +------+-------------+-------------------------------------------------------------------------------------------------------+------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |   30 | rupiah      | Rupiah Ditutup Menguat Tipis Setelah Bank Indonesia Pangkas Suku Bunga                                | bisnis     | MATA uang rupiah menguat tipis 3 poin dalam penutupan perdagangan hari ini Rabu, 17 September 2025. Nilai tukar rupiah sore ini ditutup pada level 16.437 per dolar Amerika Serikat. Pada penutupan perd... |
# +------+-------------+-------------------------------------------------------------------------------------------------------+------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |   31 | bagaimana   | Bagaimana Nasib Nasabah Dana Pensiun Usai OJK Bubarkan Jiwasraya                                      | bisnis     | OTORITAS Jasa Keuangan telah membubarkan Dana Pensiun Pemberi Kerja (DPPK) dan Dana Pensiun Lembaga Keuangan (DPLK) PT Asuransi Jiwasraya . Kepala Eksekutif Pengawas Perasuransian, Penjaminan, dan Dan... |
# +------+-------------+-------------------------------------------------------------------------------------------------------+------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |   32 | kursi       | Kursi Menteri BUMN Masih Kosong Usai Erick Thohir menjadi Menpora                                     | bisnis     | PRESIDEN Prabowo Subianto memberhentikan Erick Thohir dari jabatan Menteri Badan Usaha Milik Negara (BUMN) per hari ini Rabu, 17 September 2025. Erick mendapatkan mandat baru sebagai Menteri Pemuda da... |
# +------+-------------+-------------------------------------------------------------------------------------------------------+------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |   33 | pengadilan  | Pengadilan Putus Pailit PT Sejahtera Bintang Abadi Textile Tbk                                        | bisnis     | PENGADILAN Niaga pada Pengadilan Negeri Jakarta Pusat memutus pailit PT Sejahtera Bintang Abadi Textile Tbk (SBAT) setelah proses Penundaan Kewajiban Pembayaran Utang (PKPU) dengan nomor perkara 3/Pdt... |
# +------+-------------+-------------------------------------------------------------------------------------------------------+------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |   34 | ihsg        | IHSG Ditutup Menguat hingga Level 8.025 Setelah BI Turunkan Suku Bunga                                | bisnis     | INDEKS Harga Saham Gabungan ( IHSG ) Bursa Efek Indonesia (BEI) pada Rabu sore, 17 September 2025, ditutup menguat menembus level 8.025,18 seiring dengan kebijakan moneter Bank Indonesia (BI) yang cen... |
# +------+-------------+-------------------------------------------------------------------------------------------------------+------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |   35 | masyarakat  | Masyarakat Diminta Tak Khawatir Mengonsumsi Udang                                                     | bisnis     | KEMENTERIAN Koordinator Bidang Pangan meminta masyarakat tak khawatir mengonsumsi udang asal Indonesia, di tengah temuan udang ekspor ke Amerika Serikat (AS) yang terkontaminasi radioaktif Cesium-137.... |
# +------+-------------+-------------------------------------------------------------------------------------------------------+------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |   36 | bahlil      | Bahlil: Prabowo Akan Resmikan PLTP Lumut Balai Unit II                                                | bisnis     | MENTERI Energi dan Sumber Daya Mineral (ESDM) Bahlil Lahadalia mengatakan Presiden Prabowo Subianto akan meresmikan Pembangkit Listrik Tenaga Panas Bumi (PLTP) Lumut Balai Unit II di Muara Enim, Sumat... |
# +------+-------------+-------------------------------------------------------------------------------------------------------+------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |   37 | mengapa     | Mengapa Stimulus Ekonomi Dinilai Belum Menjawab 2 Masalah Utama                                       | bisnis     | ALIANSI Ekonom Indonesia menilai paket stimulus ekonomi yang digelontorkan pemerintah belum menjawab dua permasalahan utama darurat ekonomi Indonesia yang disuarakan oleh lebih dari 300 ekonom. Dua pe... |
# +------+-------------+-------------------------------------------------------------------------------------------------------+------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |   38 | bank        | Bank Indonesia Memperkirakan Pertumbuhan Ekonomi Semester II Membaik                                  | bisnis     | BANK Indonesia memproyeksikan pertumbuhan ekonomi pada semester II atau hingga akhir 2025 di kisaran 4,6-5,4 persen. BI mengatakan pertumbuhan ekonomi pada sisa akhir tahun ini bisa membaik karena bel... |
# +------+-------------+-------------------------------------------------------------------------------------------------------+------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |   39 | wto         | WTO Public Forum 2025 Dibuka, Soroti Peran AI dalam Perdagangan Dunia                                 | bisnis     | WORLD World Trade Organization ( WTO ) Public Forum 2025 resmi dibuka di kantor pusat WTO di Jenewa, Swiss, hari ini, Rabu, 17 September 2025. Pembukaan agenda tahunan organisasi perdagangan dunia ini... |
# +------+-------------+-------------------------------------------------------------------------------------------------------+------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |   40 | kementerian | Kementerian Pangan: 18 Kontainer Udang Ekspor Tak Terkontaminasi Radioaktif                           | bisnis     | KEMENTERIAN Koordinator Bidang Pangan memastikan 18 kontainer udang ekspor dari Indonesia yang dipulangkan ketika masih dalam perjalanan atau return on board (RoB) bebas dari kontaminasi radioaktif Ce... |
# +------+-------------+-------------------------------------------------------------------------------------------------------+------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |   41 | bmkg        | BMKG: Waspadai Hujan Lebat di Jakarta Sore dan Dinihari Nanti                                         | tekno      | BADAN Meteorologi, Klimatologi, dan Geofisika ( BMKG ) memprediksi hujan lebat yang dapat disertai petir dan angin kencang bakal mengguyur sebagian besar wilayah Jakarta dan sekitarnya (Jabodetabek) p... |
# +------+-------------+-------------------------------------------------------------------------------------------------------+------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |   42 | mobil       | Mobil Hemat Energi Bengawan Team UNS Siap Berkompetisi Internasional                                  | tekno      | BENGAWAN Team Universitas Sebelas Maret ( UNS ) meluncurkan dua mobil hemat energi karya terbaru mereka, Nirankara 3.0 dan Wirasena 3.0, pada Rabu, 17 September 2025. Peluncuran yang digelar di halama... |
# +------+-------------+-------------------------------------------------------------------------------------------------------+------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |   43 | aktivitas   | Aktivitas Kegempaan Gunung Burni Telong Meningkat                                                     | tekno      | AKTIVITAS Kegempaan Gunung Burni Telong di Bener Meriah, Aceh, kembali mengalami peningkatan dalam dua hari terakhir. Laporan tim Pusat Vulkanologi dan Mitigasi Bencana Geologi ( PVMBG ) Badan Geologi... |
# +------+-------------+-------------------------------------------------------------------------------------------------------+------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |   44 | walhi       | Walhi akan Deklarasikan Hari Keadilan Ekologis di Sumba                                               | tekno      | WAHANA Lingkungan Hidup Indonesia ( Walhi ) akan mendeklarasikan 20 September 2025 sebagai Hari Keadilan Ekologis. Rencana deklarasi ini bertepatan dengan Pertemuan Nasional Lingkungan Hidup (PNLH) XI... |
# +------+-------------+-------------------------------------------------------------------------------------------------------+------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |   45 | cara        | Cara Mengantisipasi Ledakan Gas Tabung Elpiji                                                         | tekno      | KASUS ledakan gas dari tabung elpiji (LPG) bisa sampai menimbulkan korban dan merusak bangunan rumah. Menurut dosen dari Kelompok Keahlian Ilmu dan Rekayasa Termal Institut Teknologi Bandung ( ITB ) T... |
# +------+-------------+-------------------------------------------------------------------------------------------------------+------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |   46 | nasa        | NASA Amati Eksoplanet Seukuran Bumi, Eksplorasi Awal Potensi Atmosfer                                 | tekno      | BADAN Antariksa Amerika Serikat ( NASA ) menggunakan Teleskop Luar Angkasa James Webb (JWST) tengah meneliti eksoplanet TRAPPIST-1 e, salah satu planet seukuran Bumi yang berada di zona layak huni sis... |
# +------+-------------+-------------------------------------------------------------------------------------------------------+------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |   47 | soal        | Soal Nasib TikTok di AS, Trump Pastikan Sudah Ada Pembeli                                             | tekno      | PRESIDEN Amerika Serikat Donald Trump menyatakan pemerintahannya telah mencapai kesepakatan dengan Cina soal kelanjutan operasi TikTok di Negeri Abang Sam. Dalam kesepakatan itu, aset TikTok di AS aka... |
# +------+-------------+-------------------------------------------------------------------------------------------------------+------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |   48 | menhan      | Menhan Uji Terbang Helikopter Kolaborasi PTDI dan Airbus H225M                                        | tekno      | MENTERI Pertahanan Sjafrie Sjamsoeddin mengikuti uji terbang helikopter H225M yang merupakan hasil kerja sama PT Dirgantara Indonesia ( PTDI ) dan Airbus Helicopter pada Senin, 15 September 2025. Medi... |
# +------+-------------+-------------------------------------------------------------------------------------------------------+------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |   49 | kata        | Kata Guru Besar UGM Soal Penyebab Anak Gajah Mati di Taman Nasional                                   | tekno      | KEMATIAN anak gajah bernama Kalistha Lestari atau Tari di Taman Nasional Tesso Nilo Riau pada 10 September lalu ternyata dipicu infeksi virus Elephant Endotheliotropic Herpes Viruses (EEHV). Hewan ini... |
# +------+-------------+-------------------------------------------------------------------------------------------------------+------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |   50 | google      | Google Punya Alat Pencarian Baru di Windows, Mirip Spotlight Microsoft                                | tekno      | APLIKASI baru hasil eksperimen Google bernama ‘Google App for Windows ’ menghadirkan fitur pencarian mirip Spotlight di sistem operasi Microsoft. Aplikasi ini membantu pengguna menelusuri file lokal, ... |
# +------+-------------+-------------------------------------------------------------------------------------------------------+------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |   51 | segudang    | Segudang Penyebab Banjir Bali Menurut Walhi                                                           | tekno      | WAHANA Lingkungan Hidup Indonesia ( Walhi ) mengatakan banjir besar di Bali pada 10 September lalu tidak terlepas dari dampak alih fungsi lahan akibat tekanan pembangunan. Degradasi lingkungan yang di... |
# +------+-------------+-------------------------------------------------------------------------------------------------------+------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |   52 | fakta       | Fakta-fakta Unik Ular Tanah                                                                           | tekno      | TUJUH warga suku Baduy Dalam dan Baduy Luar di pedalaman Kabupaten Lebak, Banten, dilaporkan meninggal akibat gigitan ular tanah ( Calloselasma rhodostoma ). Insiden ini terjadi dalam periode Januari ... |
# +------+-------------+-------------------------------------------------------------------------------------------------------+------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |   53 | ai          | AI Deteksi Lonjakan Gempa Kecil di Gunung Api Terganas di Eropa                                       | tekno      | PENGAMATAN berbasis akal imitasi ( AI ) belakangan membantu ilmuwan melihat aktivitas di bawah permukaan Gunung Api Campi Flegrei di Italia yang sedang bergejolak. Tim dari Universitas Stanford bersam... |
# +------+-------------+-------------------------------------------------------------------------------------------------------+------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |   54 | profil      | Profil Pourfect 60, Mesin Penyeduh Kopi Unik Buatan Mahasiswa ITB                                     | tekno      | MESIN penyeduh kopi buatan mahasiswa Institut Teknologi Bandung ( ITB ) akan dikomersialkan oleh sebuah QIMTronics, perusahaan teknologi kreatif. Alat bernama Pourfect 60 ini merupakan inovasi yang me... |
# +------+-------------+-------------------------------------------------------------------------------------------------------+------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |   55 | pokemon     | Pokemon Pokopia Masuk Nintendo Switch 2 pada 2026, Game Apa Ini?                                      | tekno      | PERMAINAN simulasi kehidupan pertama Pokemon , bernama Pokemon Pokopia, akan dirilis di Nintendo Switch 2 pada 2026. Merujuk laman resmi Pokemon.com pada 14 September lalu, dikutip dari Antara , pemai... |
# +------+-------------+-------------------------------------------------------------------------------------------------------+------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |   56 | prediksi    | Prediksi BMKG: Mayoritas Jakarta Berawan Pagi Ini, Sore Hujan Lebat                                   | tekno      | BADAN Meteorologi, Klimatologi, dan Geofisika ( BMKG ) mendeteksi potensi hujan lebat yang dapat disertai petir dan angin kencang di sebagian besar wilayah Jakarta pada hari ini, Rabu, 17 September 20... |
# +------+-------------+-------------------------------------------------------------------------------------------------------+------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |   57 | viral       | Viral Semburan Api Misterius di Pulau Bacan, Apa Kata Badan Geologi?                                  | tekno      | BADAN Geologi Kementerian Energi dan Sumber Daya Mineral (ESDM) menanggapi fenomena semburan api misterius dari arah Gunung Sibela yang berlokasi di Pulau Bacan, Halmahera Selatan, Maluku Utara. Fenom... |
# +------+-------------+-------------------------------------------------------------------------------------------------------+------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |   58 | status      | Status Gunung Lewotobi Laki-laki Diturunkan Kembali dari Awas Menjadi Siaga                           | tekno      | STATUS Gunung Lewotobi Laki-Laki di Flores Timur, Nusa Tenggara Timur, kembali diturunkan dari Level IV (Awas) menjadi Level III atau Siaga pada hari ini, Selasa, 16 September 2025. Gunung api dengan ... |
# +------+-------------+-------------------------------------------------------------------------------------------------------+------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |   59 | begini      | Begini Jatam Menilai Rezim Prabowo Setelah Satu Tambang Nikel di Raja Ampat Dipertahankan             | tekno      | PEMERINTAHAN Presiden Prabowo Subianto tak hanya mendapat titipan kerusakan dari rezim penguasa sebelumnya dalam hal perizinan tambang. Tapi ternyata juga tak berminat untuk mengevaluasinya. "Rezim Pr... |
# +------+-------------+-------------------------------------------------------------------------------------------------------+------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |   60 | konservasi  | Konservasi Hiu Paus, Evaluasi Pada Penanganan Terdampar dan Aktivitas Wisata                          | tekno      | KEBERADAAN hiu paus di perairan Indonesia masih menghadapi tantangan serius, mulai dari keterdamparan hingga praktik wisata yang belum terkelola dengan baik. Rencana Aksi Nasional Konservasi Hiu Paus ... |
# +------+-------------+-------------------------------------------------------------------------------------------------------+------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |   61 | erick       | Erick Thohir Didesak Mundur sebagai Ketua Umum PSSI setelah Jadi Menpora                              | bola       | MENTERI Pemuda dan Olahraga Erick Thohir didesak mundur dari jabatan sebagai Ketua Umum Persatuan Sepak Bola Seluruh Indonesia. Desakan itu disampaikan setelah Erick dilantik oleh Presiden Prabowo Sub... |
# +------+-------------+-------------------------------------------------------------------------------------------------------+------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |   62 | luciano     | Luciano Guaycochea Tak Sabar Jalani Laga Persib Bandung vs Lion City Sailors                          | bola       | GELANDANG Persib Bandung Luciano Guaycochea mengatakan tak sabar menantikan laga perdana penyisihan Grup H AFC Champions League Two kontra Lion City Sailors. Pertandingan ini dijadwalkan berlangsung d... |
# +------+-------------+-------------------------------------------------------------------------------------------------------+------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |   63 | bojan       | Bojan Hodak Sebut Persib Bandung Tak Diunggulkan Lawan Lion City Sailors                              | bola       | PELATIH Persib Bandung Bojan Hodak mengatakan tim asuhnya tidak diunggulkan dalam laga perdana penyisihan Grup G AFC Champions League Two melawan Lion City Sailors. Pertandingan ini akan digelar di St... |
# +------+-------------+-------------------------------------------------------------------------------------------------------+------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |   64 | jadwal      | Jadwal Liga Champions Rabu Malam 17 September: Ada Liverpool vs Atletico Madrid                       | bola       | JADWAL Liga Champions 2025/2026 memasuki babak utama atau babak liga. Sejumlah pertandingan sudah dimainkan pada Selasa dan akan berlanjut pada Rabu malam, 17 September 2025, hingga Jumat dinihari WI...  |
# +------+-------------+-------------------------------------------------------------------------------------------------------+------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |   65 | kylian      | Kylian Mbappe: Real Madrid Bawa Semangat Liga Champions ke Bernabeu                                   | bola       | PEMAIN depan Real Madrid, Kylian Mbappe , mengatakan timnya membawa semangat Liga Champions ke Santiago Bernabeu saat Los Blancos menang 2-1 atas Marseille pada pertandingan pertama Liga Champions 202... |
# +------+-------------+-------------------------------------------------------------------------------------------------------+------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |   66 | pssi        | PSSI Lobi FIFA dan AFC Soal Wasit yang Pimpin Laga Timnas Indonesia di Kualifikasi Piala Dunia 2026   | bola       | KETUA Umum PSSI Erick Thohir ingin wasit yang memimpin laga timnas Indonesia melawan Arab Saudi dan Irak pada putaran keempat Kualifikasi Piala Dunia 2026 zona Asia Grup B pada Oktober nanti berasal d... |
# +------+-------------+-------------------------------------------------------------------------------------------------------+------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |   67 | 5           | 5 Cerita Menarik dari Kemenangan Real Madrid atas Marseille di Liga Champions                         | bola       | KLUB asal Spanyol Real Madrid berhasil memenangi laga pertama Liga Champions musim 2025/2026. Mereka mengalahkan Marseille (Prancis) dengan skor 2-1 dalam pertandingan di Santiago Bernabeu, Rabu dinih... |
# +------+-------------+-------------------------------------------------------------------------------------------------------+------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# ...
# |   78 | timnas      | Timnas U-17 Indonesia Direncanakan TC di Dubai pada Oktober                                           | bola       | TIMNAS U-17 Indonesia diagendakan melanjutkan pemusatan latihan atau TC di Dubai setelah laga uji coba di Bulgaria. Agenda ini bertujuan mematangkan persiapan menghadapi Piala Dunia U-17 2025....         |
# +------+-------------+-------------------------------------------------------------------------------------------------------+------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |   79 | jadwal      | Jadwal Persib Bandung di Laga Pertama Grup AFC Champions League Two pada Kamis Pekan Ini              | bola       | PERSIB Bandung akan menjalani laga pertama Grup G AFC Champions League Two (ACL Two) 2025/26 menghadapi Lion City Sailors di Stadion Gelora Bandung Lautan Api (GBLA), Bandung, Kamis, 18 September 2025... |
# +------+-------------+-------------------------------------------------------------------------------------------------------+------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |   80 | jadwal      | Jadwal Lengkap Liga Champions 2025-2026 Pekan Pertama                                                 | bola       | KOMPETISI Liga Champions 2025-2026 mulai bergulir pada Selasa, 16 September 2025. Sebanyak 18 pertandingan akan tersaji, dengan empat di antaranya berstatus sebagai laga besar. Empat pertandingan besa... |
# +------+-------------+-------------------------------------------------------------------------------------------------------+------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |   81 | kejagung    | Kejagung Limpahkan Tiga Tersangka Kasus Sritex ke Kejaksaan Surakarta                                 | metro      | PROSES hukum atas kasus dugaan korupsi pemberian fasilitas kredit kepada PT Sri Rejeki Isman Tbk ( Sritex ) memasuki tahap kedua. Penyidik dari Jaksa Agung Muda Bidang Tindak Pidana Khusus (Jampidsus)... |
# +------+-------------+-------------------------------------------------------------------------------------------------------+------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |   82 | ruu         | RUU Hak Cipta Diusulkan Masuk Prolegnas Prioritas 2026                                                | metro      | KOMISI XIII Dewan Perwakilan Rakyat Republik Indonesia (DPR RI) mengusulkan Rancangan Undang-Undang (RUU) Hak Cipta dimasukkan dalam Program Legislasi Nasional (Prolegnas) Prioritas 2026. Regulasi ini... |
# +------+-------------+-------------------------------------------------------------------------------------------------------+------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |   83 | polisi      | Polisi Temukan Satu Orang Hilang yang Dilaporkan ke KontraS                                           | metro      | KEPOLISIAN Daerah Metropolitan Jakarta Raya telah menemukan Bima Permana Putra, satu dari tiga orang hilang yang dilaporkan ke Komisi untuk Orang Hilang dan Korban Tindak Kekerasan (KontraS) setelah k... |
# +------+-------------+-------------------------------------------------------------------------------------------------------+------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |   84 | revisi      | Revisi UU Perlindungan Saksi dan korban: Kewenangan LPSK Diperkuat                                    | metro      | PEMBAHASAN revisi Undang-Undang Perlindungan Saksi dan Korban (UU PSK) di Komisi XIII DPR RI menyoroti perlunya perubahan paradigma terhadap posisi korban tindak pidana. Anggota dewan Komisi Hukum ber... |
# +------+-------------+-------------------------------------------------------------------------------------------------------+------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |   85 | kpk         | KPK Tunggu Penghitungan BPKP Untuk Tahan Indra Iskandar Cs                                            | metro      | KOMISI Pemberantasan Korupsi (KPK) masih menunggu perhitungan kerugian dari Badan Pengawasan Keuangan dan Pembangunan (BPKP) untuk menahan tujuh tersangka korupsi pengadaan kelengkapan rumah dinas Dew... |
# +------+-------------+-------------------------------------------------------------------------------------------------------+------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |   86 | polisi      | Polisi Gagalkan Penyelundupan Benih Bening Lobster Senilai Rp 7,5 Miliar di Cianjur                   | metro      | KORPS Kepolisian Perairan dan Udara (Korpolairud) Badan Pemeliharaan Keamanan (Baharkam) Polri menggagalkan penyelundupan 50 ribu ekor benih bening lobster (BBL) senilai Rp 7,5 miliar di Cidaun, Kabup... |
# +------+-------------+-------------------------------------------------------------------------------------------------------+------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |   87 | kpk         | KPK Sampaikan Alasan Belum Tahan Tersangka Korupsi Pengadaan EDC BRI                                  | metro      | KOMISI Pemberantasan Korupsi (KPK) belum menahan lima tersangka korupsi pengadaan mesin electronic data capture (EDC) di PT Bank Rakyat Indonesia. Juru bicara KPK Budi Prasetyo mengatakan penyidik mas... |
# +------+-------------+-------------------------------------------------------------------------------------------------------+------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |   88 | saksi       | Saksi Akui Uang yang Diberikan Djuyamto untuk Bangun Kantor NU                                        | metro      | JAKSA Penuntut Umum menghadirkan saksi bernama Suratno dalam sidang kasus suap vonis lepas perkara minyak sawit mentah (crude palm oil/CPO) pada Rabu, 17 September 2025. Sidang berlangsung di Pengadil... |
# +------+-------------+-------------------------------------------------------------------------------------------------------+------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |   89 | pembahasan  | Pembahasan Rancangan KUHAP di DPR Dilanjutkan Oktober                                                 | metro      | KOMISI III Dewan Perwakilan Rakyat (DPR) akan melanjutkan pembahasan Rancangan Undang-Undang tentang Hukum Acara Pidana ( KUHAP ) pada Oktober mendatang. “Oktober akan lanjut kembali dan diharapkan ka... |
# +------+-------------+-------------------------------------------------------------------------------------------------------+------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |   90 | polri       | Polri Salurkan Beras Subsidi dan Minyak dalam Gerakan Pangan Murah                                    | metro      | POLRI menggelar Gerakan Pangan Murah di Markas Staf Logistik Polri, Cipinang, Jakarta Timur, Rabu, 17 September 2025. Kegiatan ini menyediakan beras, minyak goreng, dan gula pasir dengan harga di bawa... |
# +------+-------------+-------------------------------------------------------------------------------------------------------+------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |   91 | polisi      | Polisi Tetapkan Dua Tersangka Pencurian Motor Jakarta Pusat                                           | metro      | POLISI menetapkan dua orang sebagai tersangka kasus pencurian sepeda motor yang terjadi di wilayah Jakarta Pusat. Tersangka berinisial R (26 tahun) dan M (39 tahun) memiliki peran sebagai pelaku pencu... |
# +------+-------------+-------------------------------------------------------------------------------------------------------+------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |   92 | hakim       | Hakim Tunda Putusan untuk Windu Aji Sutanto dan Gleen Ario                                            | metro      | MAJELIS Hakim Pengadilan Tindak Pidana Korupsi pada Pengadilan Negeri Jakarta Pusat menunda sidang putusan terhadap Windu Aji Sutanto dan Glenn Ario Sudarto. Windu dan Glenn adalah terdakwa tindak pid... |
# +------+-------------+-------------------------------------------------------------------------------------------------------+------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |   93 | kpk         | KPK Panggil Lima Pejabat Kemenag Usut Dugaan Korupsi Kuota Haji                                       | metro      | KOMISI Pemberantasan Korupsi ( KPK ) masih terus mendalami dugaan tindak pidana korupsi kuota haji tahun 2023-2024. Lima orang pejabat dan pegawai Kementerian Agama diperiksa hari ini, Rabu, 17 Septem... |
# +------+-------------+-------------------------------------------------------------------------------------------------------+------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |   94 | aliansi     | Aliansi Perempuan Indonesia Tabur Bunga di Polda Metro Jaya                                           | metro      | PULUHAN aktivis perempuan yang tergabung dalam Aliansi Perempuan Indonesia menggelar aksi tabur bunga di depan gerbang Polda Metro Jaya , Jakarta Selatan, Rabu, 17 September 2025. Mereka mendesak pemb... |
# +------+-------------+-------------------------------------------------------------------------------------------------------+------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |   95 | ky          | KY Soroti DPR yang Hanya Setujui Satu Hakim Ad Hoc HAM: Tidak Efektif                                 | metro      | DEWAN Perwakilan Rakyat telah menetapkan sembilan calon hakim agung dan satu calon hakim ad hoc Hak Asasi Manusia di Mahkamah Agung....                                                                     |
# +------+-------------+-------------------------------------------------------------------------------------------------------+------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |   96 | deretan     | Deretan Polisi Jenderal Bintang Tiga di Tengah Bursa Kapolri                                          | metro      | MENTERI Sekretaris Negara Prasetyo Hadi mengatakan Presiden Prabowo Subianto belum mengirim surat presiden (surpres) soal pergantian sosok Kapolri ke DPR. Pernyataan Prasetyo membantah isu Kapolri Jen... |
# +------+-------------+-------------------------------------------------------------------------------------------------------+------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |   97 | polisi      | Polisi akan Kembalikan Dua Kucing Uya Kuya yang Dijarah                                               | metro      | POLRES Jakarta Timur segera mengembalikan dua kucing milik anggota DPR Surya Utama atau Uya Kuya yang sempat dievakuasi dalam penangkapan pelaku penjarahan....                                             |
# +------+-------------+-------------------------------------------------------------------------------------------------------+------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |   98 | yusril      | Yusril: Komisi Reformasi Polri Tak Berkaitan dengan Pergantian Kapolri                                | metro      | MENTERI Koordinator Bidang Hukum, Hak Asasi Manusia, Imigrasi dan Pemasyarakatan Yusril Ihza Mahendra mengatakan rencana pembentukan Komisi Reformasi Kepolisian tak berkaitan dengan isu pergantian Kap... |
# +------+-------------+-------------------------------------------------------------------------------------------------------+------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |   99 | jaksa       | Jaksa Hadirkan Istri Hakim Djuyamto hingga Advokat dalam Sidang Suap Vonis CPO                        | metro      | JAKSA Penuntut Umum (JPU) menghadirkan lima orang saksi dalam sidang kasus suap vonis lepas perkara minyak sawit mentah ( crude palm oil /CPO) pada hari ini, Rabu, 17 September 2025. Sidang berlangsun... |
# +------+-------------+-------------------------------------------------------------------------------------------------------+------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |  100 | polri       | Polri Klaim Sudah Bergerak Cari Tiga Orang Hilang Usai Demonstrasi                                    | metro      | POLRI mengklaim sudah mengambil langkah untuk menelusuri tiga orang yang dilaporkan hilang usai demonstrasi ricuh di Jakarta pada akhir Agustus lalu. Kepala Biro Penerangan Masyarakat Divisi Humas Pol... |
# +------+-------------+-------------------------------------------------------------------------------------------------------+------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+

# %% [markdown]
# # Penjelasan Kode Scraping RSS Tempo
#
# Kode ini bertujuan untuk **mengambil berita dari RSS Tempo** berdasarkan beberapa kategori, lalu menyimpannya ke file **CSV**.
#
# ---
#
# ## Alur Kerja Program
#
# 1. **Menentukan daftar kategori**
#    Daftar kategori berita sudah ditentukan:
#    - nasional
#    - bisnis
#    - tekno
#    - bola
#    - metro
#    - dunia
#
#    Dari tiap kategori, program membentuk URL RSS, misalnya:
#
# 2. **Mengambil RSS feed**
# - Program mengirim request menggunakan `requests`.
# - Jika request gagal → kategori dilewati.
# - Jika berhasil → konten diproses dengan **BeautifulSoup** (mode XML) untuk menemukan semua elemen `<item>` yang berisi berita.
#
# 3. **Membatasi jumlah berita**
# Dari setiap kategori, hanya **20 berita pertama** yang akan diproses.
#
# 4. **Mengambil informasi berita**
# Dari setiap `<item>`, program mengambil:
# - **Link berita** dari `<link>`
# - **Judul berita** dari `<title>`
# - **ID berita**, dengan cara memotong bagian URL
#
# 5. **Membuka halaman berita asli**
# - Program membuka link berita dengan `requests`.
# - Jika halaman berhasil dibuka → konten berita diambil dari `<div id="content-wrapper">`.
# - Elemen yang tidak relevan seperti `<script>`, `<style>`, `<aside>`, dan `<figure>` dihapus.
# - Semua paragraf `<p>` digabung jadi satu teks panjang.
# - Bagian teks **“Baca juga…”** dihapus menggunakan regex.
#
# 6. **Ringkasan isi berita**
# - Jika isi berhasil didapat, dibuat ringkasan berupa **200 karakter pertama**.
# - Jika gagal, isi diganti dengan tanda `-`.
#
# 7. **Menyimpan hasil**
# - Setiap berita dicatat dalam list `results` dengan format:
#   ```
#   [No, ID Berita, Judul, Kategori, Isi Ringkas]
#   ```
# - Untuk menghindari beban server, ada jeda `time.sleep(1)` setiap kali memproses berita.
#
# 8. **Membuat DataFrame dan CSV**
# - Semua hasil dikonversi ke **Pandas DataFrame** dengan kolom:
#   ```
#   No | ID Berita | Judul | Kategori | Isi
#   ```
# - DataFrame disimpan ke file **berita_tempo.csv** dengan encoding UTF-8.
#
# ---
#
# ## Hasil Akhir
# - File `berita_tempo.csv` berisi daftar berita dari berbagai kategori.
# - Isi berita ditampilkan dalam bentuk ringkasan agar tidak terlalu panjang.

# %%
from google.colab import files
files.download("/content/berita_tempo.csv")

# %% [markdown]
# Simpan dalam bentuk csv
